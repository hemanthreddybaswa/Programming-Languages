# %% [markdown]
# ### Python

# %%
'''
Python is a general-purpose, interpreted, interactive, object-oriented, and high-level
programming language. It was created by Guido van Rossum during 1985 - 1990. Like
Perl, Python source code is also available under the GNU General Public License (GPL).
Python is named after a TV Show called 'Monty Python's Flying Circus' and not after
Python-the snake.
Python is a open source language.
Python 3.0 was released in 2008.
'''
# Out:
# "\nPython is a general-purpose, interpreted, interactive, object-oriented, and high-level\nprogramming language. It was created by Guido van Rossum during 1985 - 1990. Like\nPerl, Python source code is also available under the GNU General Public License (GPL).\nPython is named after a TV Show called 'Monty Python's Flying Circus' and not after\nPython-the snake.\nPython is a open source language.\nPython 3.0 was released in 2008.\n"

# %%
'''
Difference btw python and python-3

1.The __future__ module
Python 3
Python 3.x introduced some Python 2-incompatible keywords and features that can be
imported via the in-built __future__ module in Python 2. It is recommended to use
__future__ imports, if you are planning Python 3.x support for your code.
For example, if we want Python 3.x's integer division behavior in Python 2, add the
following import statement.

2.The print Function
Most notable and most widely known change in Python 3 is how the print function is used.
Use of parenthesis () with print function is now mandatory. It was optional in Python 2.
It is a statement. print "Hello" in pthon 2
It is a built-in function. print("Hello") in python 3

3.Python 2 has two versions of input functions, input() and raw_input(). 
The input() function treats the received data as string if it is included in quotes '' or "", otherwise the
data is treated as number.
In Python 3, raw_input() function is deprecated. Further, the received data is always
treated as string.

4.In Python 2, the result of division of two integers is rounded to the nearest integer. As a
result, 3/2 will show 1. In order to obtain a floating-point division, numerator or
denominator must be explicitly used as float. Hence, either 3.0/2 or 3/2.0 or 3.0/2.0 will
result in 1.5
Python 3 evaluates 3 / 2 as 1.5 by default, which is more intuitive for new programmers.

5.Strings are ASCII by default in pyhton 2.	Strings are Unicode by default, making it much easier to support
 multiple languages and emojis in python 3.

6.xrange() Function Removed
In Python 2 range() returns a list, and xrange() returns an object that will only generate
the items in the range when needed, saving memory.
In Python 3, the range() function is removed, and xrange() has been rename.

7.Arguments in Exceptions
In Python 3, arguments to exception should be declared with 'as' keyword.
except Myerror, err: # In Python2
except Myerror as err: #In Python3

'''
# Out:
# '\nDifference btw python and python-3\n\n1.The __future__ module\nPython 3\nPython 3.x introduced some Python 2-incompatible keywords and features that can be\nimported via the in-built __future__ module in Python 2. It is recommended to use\n__future__ imports, if you are planning Python 3.x support for your code.\nFor example, if we want Python 3.x\'s integer division behavior in Python 2, add the\nfollowing import statement.\n\n2.The print Function\nMost notable and most widely known change in Python 3 is how the print function is used.\nUse of parenthesis () with print function is now mandatory. It was optional in Python 2.\nIt is a statement. print "Hello" in pthon 2\nIt is a built-in function. print("Hello") in python 3\n\n3.Python 2 has two versions of input functions, input() and raw_input(). \nThe input() function treats the received data as string if it is included in quotes \'\' or "", otherwise the\ndata is treated as number.\nIn Python 3, raw_input() function is deprecat
# ...

# %%
'''
Python's features :

Easy-to-learn: Python has few keywords, simple structure, and a clearly defined
syntax. This allows a student to pick up the language quickly.

Interpreted: Python executes code line-by-line. If there is an error, it stops 
and reports it immediately. 
This makes testing and debugging much easier compared
to languages that compile everything at once before running.

Dynamically Typed: You do not have to explicitly declare what type of data 
a variable holds (like an integer, text string, or decimal). 
Python figures it out automatically when the program runs.

standard library: Python's bulk of the library is very portable and 
cross-platform compatible on UNIX, Windows, and Macintosh.

Multi-Paradigm: Python does not force you into one specific way of 
structuring your code. You can write code using an Object-Oriented approach, 
a Functional approach, or just write simple, sequential scripts.

Platform Independent: Python is cross-platform. 
Code written in Python on a Mac will run perfectly on Windows or Linux without
needing to be rewritten.

Interactive Mode: Python has support for an interactive mode, which allows 
interactive testing and debugging of snippets of code.

Portable: Python can run on a wide variety of hardware platforms and has the 
same interface on all platforms.

Extendable: You can add low-level modules to the Python interpreter. These
modules enable programmers to add to or customize their tools.

Databases: Python provides interfaces to all major commercial databases.

GUI Programming: Python supports GUI applications that can be created and
ported to many system calls, libraries and windows systems, such as Windows
MFC, Macintosh, and the X Window system of Unix.

'''
# Out:
# "\nPython's features :\n\nEasy-to-learn: Python has few keywords, simple structure, and a clearly defined\nsyntax. This allows a student to pick up the language quickly.\n\nInterpreted: Python executes code line-by-line. If there is an error, it stops \nand reports it immediately. \nThis makes testing and debugging much easier compared\nto languages that compile everything at once before running.\n\nDynamically Typed: You do not have to explicitly declare what type of data \na variable holds (like an integer, text string, or decimal). \nPython figures it out automatically when the program runs.\n\nstandard library: Python's bulk of the library is very portable and \ncross-platform compatible on UNIX, Windows, and Macintosh.\n\nMulti-Paradigm: Python does not force you into one specific way of \nstructuring your code. You can write code using an Object-Oriented approach, \na Functional approach, or just write simple, sequential scripts.\n\nPlatform Independent: Python is cross-platfor
# ...
